# %%
from src.load import *
from src.config import *

# %%
beneficiary = load_claim_from_path(Beneficiary_paths)
beneficiary.to_pickle("data/cache/beneficiary.pkl")

# %%
carrier = load_claim_from_path(Carrier_paths)
carrier.head()
carrier.to_pickle("data/cache/carrier.pkl")

# %%
inpatient = pd.read_csv(Inpatient_path, low_memory=False)
inpatient.to_pickle("data/cache/inpatient.pkl")

outpatient = pd.read_csv(Outpatient_path, low_memory=False)
outpatient.to_pickle("data/cache/outpatient.pkl")

pde = pd.read_csv(Pde_path, low_memory=False)
pde.to_pickle("data/cache/pde.pkl")
